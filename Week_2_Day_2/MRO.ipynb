# %%
class A:
    def show(self):
        print('A')
        
class B(A):
    pass

class C(A):
    pass
class D(B,C):
    pass

# %%
import colorsys
import turtle
t = turtle.Turtle()
s=turtle.Screen().bgcolor("black")
t.speed(0)
n =70
h=0
for i in range(360):
  c =colorsys.hsv_to_rgb(h ,1 ,0.8)
  h += 1/n
  t.color(c)
  t.left(1)
  t.fd(1)
  for j in range(2):
    t.left(2)
    t.circle(100)
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[2], line 12
#       8 for i in range(360):
#       9   c =colorsys.hsv_to_rgb(h ,1 ,0.8)
#      10   h += 1/n
#      11   t.color(c)
# ---> 12   t.left(1)
#      13   t.fd(1)
#      14   for j in range(2):
#      15     t.left(2)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\Lib\turtle.py:1713, in TNavigator.left(self, angle)
#    1694 def left(self, angle):
#    1695     """Turn turtle left by angle units.
#    1696
#    1697     Aliases: left | lt
#    (...)   1711     67.0
#    1712     """
# -> 1713     self._rotate(angle)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3824.0_x64__qbz5n2kfra8p0\Lib\turtle.py:3342, in RawTurtle._rotate(self, angle)
#    3340         self._update()
#    3341 self._orient = neworient
# ...
